# %% [markdown]
# ## Ejercicios

# %% [markdown]
# **Ejercicio 1: Especies de Plantas**
#
# Haz una lista con los nombres científicos (solo género y especie) de las siguientes 5 plantas:
#
#
#
# *   Abedul (*Betula alba*)
# *   Pino negro (*Pinus uncinata*)
# *   Pino silvestre (*Pinus sylvestris*)
# *   Pino piñonero (*Pinus pinea*)
# *   Tomillo (*Thymus vulgaris*)
#
#
# Imprime con el siguiente formato por cada especie:
#
# "El género es {genero} y la especie es {especie}"
#
# Por último, cuenta el número de espcies con Género *Pinus*

# %% [markdown]
# **Ejercicio 2: Cuenta las bases**
#
# Dada la siguiente secuecnia de ADN haz una función que cuente las apariciones de cada base.

# %%
dna = "..."

# %%
def count_base(dna):
  # El codigo aqui
  return count_a, count_c, count_g, count_t

# %% [markdown]
# ### EXTRA:
#
# Ejecuta lo que hay dentro para ver una gráfica con la solución.

# %%
import matplotlib.pyplot as plt

a,c,g,t = count_base(dna)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
bases = ['A', 'C', 'G', 'T']
counts = [a,c,g,t]
ax.bar(bases,counts)
plt.show()
